# %%
from num2words.detect_convert_ch_numbers import convert_numbers,detect_number_spans
# from num2words.num2words_CH import num2words
# from num2words.lang_CH_BS import Num2Word_CH_BS
# from num2words.lang_CH_SG import Num2Word_CH_SG
# import spacy
# import pandas as pd
from py_heideltime.py_heideltime import heideltime

# %%
convert_numbers("Am 20.12.2024 treffen wir uns.",dialect="ch_bs")
# Out:
# Dec 23, 2025 3:15:40 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Processing started
# [NumberSpan(kind='DATE', text='20.12.2024', start=3, end=13, value={'YEAR': 2024, 'MONTH': 12, 'DAY': 20})]
# Dec 23, 2025 3:15:40 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Processing finished
# Dec 23, 2025 3:15:40 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Result formatted
# 'Am zwanzigste Dezämber zweitusigvieräzwanzig treffen wir uns.'
